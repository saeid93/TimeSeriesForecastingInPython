# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-01-29 15:56:47.308819: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-29 15:56:47.311560: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-29 15:56:47.347365: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-29 15:56:47.347383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-29 15:56:47.348387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-29 15:56:47.354321: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-29 15:56:47.355198: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-29 15:56:48.167239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Single-step model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

mae_val = [0.083, 0.068, 0.033]
mae_test = [0.081, 0.068, 0.029]

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 7s 12ms/step - loss: 0.0274 - mean_absolute_error: 0.1179 - val_loss: 0.0111 - val_mean_absolute_error: 0.0768
# Epoch 2/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0074 - mean_absolute_error: 0.0618 - val_loss: 0.0050 - val_mean_absolute_error: 0.0509
# Epoch 3/50
# 384/384 [==============================] - 4s 12ms/step - loss: 0.0046 - mean_absolute_error: 0.0486 - val_loss: 0.0038 - val_mean_absolute_error: 0.0438
# Epoch 4/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0443 - val_loss: 0.0033 - val_mean_absolute_error: 0.0410
# Epoch 5/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0414 - val_loss: 0.0029 - val_mean_absolute_error: 0.0377
# Epoch 6/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0381 - val_loss: 0.0025 - val_mean_absolute_error: 0.0346
# Epoch 7/50
# 384/384 [==============================] - 4s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0361 - val_loss: 0.0024 - val_mean_absolute_error: 0.0338
# Epoch 8/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0349 - val_loss: 0.0023 - val_mean_absolute_error: 0.0329
# Epoch 9/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0342 - val_loss: 0.0021 - val_mean_absolute_error: 0.0316
# Epoch 10/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0336 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 11/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 0.0020 - val_mean_absolute_error: 0.0309
# Epoch 12/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0326 - val_loss: 0.0019 - val_mean_absolute_error: 0.0298
# Epoch 13/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0320 - val_loss: 0.0019 - val_mean_absolute_error: 0.0303
# Epoch 14/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0316 - val_loss: 0.0019 - val_mean_absolute_error: 0.0295
# Epoch 15/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0314 - val_loss: 0.0019 - val_mean_absolute_error: 0.0312
# Epoch 16/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0310 - val_loss: 0.0018 - val_mean_absolute_error: 0.0289
# Epoch 17/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0020 - val_mean_absolute_error: 0.0320
# Epoch 18/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0303 - val_loss: 0.0018 - val_mean_absolute_error: 0.0285
# Epoch 19/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0017 - val_mean_absolute_error: 0.0279
# Epoch 20/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0298 - val_loss: 0.0016 - val_mean_absolute_error: 0.0271
# Epoch 21/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0018 - val_mean_absolute_error: 0.0302
# Epoch 22/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0295 - val_loss: 0.0017 - val_mean_absolute_error: 0.0275
# Epoch 23/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0016 - val_mean_absolute_error: 0.0271
# Epoch 24/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0016 - val_mean_absolute_error: 0.0271
# Epoch 25/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0288 - val_loss: 0.0016 - val_mean_absolute_error: 0.0272
# Epoch 26/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0286 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 27/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0286 - val_loss: 0.0016 - val_mean_absolute_error: 0.0275
# 109/109 [==============================] - 1s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0275

# %%
wide_window.plot(lstm_model)

plt.savefig('figures/CH15_F09_peixeiro.png', dpi=300)

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F10_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-step model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

ms_mae_val = [0.352, 0.347, 0.088, 0.078]
ms_mae_test = [0.347, 0.341, 0.076, 0.064]

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 3s 6ms/step - loss: 0.0483 - mean_absolute_error: 0.1583 - val_loss: 0.0210 - val_mean_absolute_error: 0.1011
# Epoch 2/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0169 - mean_absolute_error: 0.0898 - val_loss: 0.0181 - val_mean_absolute_error: 0.0928
# Epoch 3/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0151 - mean_absolute_error: 0.0832 - val_loss: 0.0168 - val_mean_absolute_error: 0.0855: 1s - loss: 0.0156
# Epoch 4/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0145 - mean_absolute_error: 0.0809 - val_loss: 0.0164 - val_mean_absolute_error: 0.0840
# Epoch 5/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0142 - mean_absolute_error: 0.0795 - val_loss: 0.0167 - val_mean_absolute_error: 0.0885
# Epoch 6/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0139 - mean_absolute_error: 0.0787 - val_loss: 0.0157 - val_mean_absolute_error: 0.0825
# Epoch 7/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0779 - val_loss: 0.0154 - val_mean_absolute_error: 0.0819
# Epoch 8/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0136 - mean_absolute_error: 0.0771 - val_loss: 0.0152 - val_mean_absolute_error: 0.0816
# Epoch 9/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0762 - val_loss: 0.0150 - val_mean_absolute_error: 0.0805
# Epoch 10/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0132 - mean_absolute_error: 0.0755 - val_loss: 0.0149 - val_mean_absolute_error: 0.0822
# Epoch 11/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0751 - val_loss: 0.0148 - val_mean_absolute_error: 0.0784
# Epoch 12/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0748 - val_loss: 0.0148 - val_mean_absolute_error: 0.0811
# Epoch 13/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0741 - val_loss: 0.0145 - val_mean_absolute_error: 0.0789
# Epoch 14/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0734 - val_loss: 0.0145 - val_mean_absolute_error: 0.0800
# Epoch 15/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0733 - val_loss: 0.0143 - val_mean_absolute_error: 0.0776
# Epoch 16/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0728 - val_loss: 0.0139 - val_mean_absolute_error: 0.0764
# Epoch 17/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0122 - mean_absolute_error: 0.0722 - val_loss: 0.0141 - val_mean_absolute_error: 0.0764
# Epoch 18/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0121 - mean_absolute_error: 0.0718 - val_loss: 0.0138 - val_mean_absolute_error: 0.0769
# Epoch 19/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0714 - val_loss: 0.0137 - val_mean_absolute_error: 0.0743
# Epoch 20/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0710 - val_loss: 0.0133 - val_mean_absolute_error: 0.0751
# Epoch 21/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0702 - val_loss: 0.0134 - val_mean_absolute_error: 0.0750
# Epoch 22/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0115 - mean_absolute_error: 0.0697 - val_loss: 0.0130 - val_mean_absolute_error: 0.0751
# Epoch 23/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0114 - mean_absolute_error: 0.0695 - val_loss: 0.0130 - val_mean_absolute_error: 0.0728
# Epoch 24/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0689 - val_loss: 0.0129 - val_mean_absolute_error: 0.0719
# Epoch 25/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0112 - mean_absolute_error: 0.0684 - val_loss: 0.0130 - val_mean_absolute_error: 0.0720
# Epoch 26/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0111 - mean_absolute_error: 0.0680 - val_loss: 0.0126 - val_mean_absolute_error: 0.0699
# Epoch 27/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0110 - mean_absolute_error: 0.0679 - val_loss: 0.0128 - val_mean_absolute_error: 0.0704
# Epoch 28/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0109 - mean_absolute_error: 0.0672 - val_loss: 0.0124 - val_mean_absolute_error: 0.0705
# Epoch 29/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0671 - val_loss: 0.0122 - val_mean_absolute_error: 0.0695
# Epoch 30/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0670 - val_loss: 0.0126 - val_mean_absolute_error: 0.0746
# Epoch 31/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0666 - val_loss: 0.0122 - val_mean_absolute_error: 0.0710
# Epoch 32/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0663 - val_loss: 0.0119 - val_mean_absolute_error: 0.0691
# Epoch 33/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0106 - mean_absolute_error: 0.0659 - val_loss: 0.0123 - val_mean_absolute_error: 0.0693
# Epoch 34/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0105 - mean_absolute_error: 0.0656 - val_loss: 0.0120 - val_mean_absolute_error: 0.0710
# Epoch 35/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0105 - mean_absolute_error: 0.0655 - val_loss: 0.0123 - val_mean_absolute_error: 0.0700
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0700

# %%
multi_window.plot(ms_lstm_model)

plt.savefig('figures/CH15_F11_peixeiro.png', dpi=300)

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F12_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-output model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
# Values from chapter 14

mo_mae_val = [0.048, 0.039, 0.023]
mo_mae_test = [0.047, 0.036, 0.020]

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0208 - mean_absolute_error: 0.0945 - val_loss: 0.0080 - val_mean_absolute_error: 0.0567
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0460 - val_loss: 0.0037 - val_mean_absolute_error: 0.0384
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0367 - val_loss: 0.0027 - val_mean_absolute_error: 0.0341
# Epoch 4/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0332 - val_loss: 0.0022 - val_mean_absolute_error: 0.0308s: 0.0028 - mean_absolute_
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0309 - val_loss: 0.0020 - val_mean_absolute_error: 0.0290
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0289 - val_loss: 0.0018 - val_mean_absolute_error: 0.0273
# Epoch 7/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0274 - val_loss: 0.0016 - val_mean_absolute_error: 0.0261
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0261 - val_loss: 0.0015 - val_mean_absolute_error: 0.0248
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0254 - val_loss: 0.0015 - val_mean_absolute_error: 0.0245
# Epoch 10/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0015 - val_mean_absolute_error: 0.0241
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0243 - val_loss: 0.0014 - val_mean_absolute_error: 0.0234
# Epoch 12/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0240 - val_loss: 0.0014 - val_mean_absolute_error: 0.0237
# Epoch 13/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.0014 - val_mean_absolute_error: 0.0230
# Epoch 14/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0235 - val_loss: 0.0013 - val_mean_absolute_error: 0.0229
# Epoch 15/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0234 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 16/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0231 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 17/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0230 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 18/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0228 - val_loss: 0.0013 - val_mean_absolute_error: 0.0221
# Epoch 19/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0226 - val_loss: 0.0012 - val_mean_absolute_error: 0.0225
# Epoch 20/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0225 - val_loss: 0.0013 - val_mean_absolute_error: 0.0220
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0223 - val_loss: 0.0012 - val_mean_absolute_error: 0.0211
# Epoch 22/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0221 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0221 - val_loss: 0.0012 - val_mean_absolute_error: 0.0221
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0219 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0210
# Epoch 26/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0216 - val_loss: 0.0011 - val_mean_absolute_error: 0.0203
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0215 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 28/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 29/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0201
# Epoch 30/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0211 - val_loss: 0.0011 - val_mean_absolute_error: 0.0205
# Epoch 31/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 0.0010 - val_mean_absolute_error: 0.0200
# Epoch 32/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 0.0010 - val_mean_absolute_error: 0.0199
# Epoch 33/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 9.9742e-04 - val_mean_absolute_error: 0.0199
# Epoch 34/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0204
# Epoch 35/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0207 - val_loss: 9.8188e-04 - val_mean_absolute_error: 0.0196
# Epoch 36/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 9.8649e-04 - val_mean_absolute_error: 0.0196
# Epoch 37/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.7301e-04 - val_mean_absolute_error: 0.0194
# Epoch 38/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.5001e-04 - val_mean_absolute_error: 0.0190
# Epoch 39/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 9.8970e-04 - val_mean_absolute_error: 0.0197
# Epoch 40/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 9.7912e-04 - val_mean_absolute_error: 0.0197
# Epoch 41/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 9.8057e-04 - val_mean_absolute_error: 0.0195
# 109/109 [==============================] - ETA: 0s - loss: 9.8921e-04 - mean_absolute_error: 0.019 - 0s 2ms/step - loss: 9.8057e-04 - mean_absolute_error: 0.0195

# %%
mo_wide_window.plot(mo_lstm_model)

plt.savefig('figures/CH15_F13_peixeiro.png', dpi=300)

# %%
mo_wide_window.plot(model=mo_lstm_model, plot_col='temp')

plt.savefig('figures/CH15_F14_peixeiro.png', dpi=300)

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F15_peixeiro.png', dpi=300)
